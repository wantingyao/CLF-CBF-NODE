# %% [markdown]
# # Install and import libraries

# %%
pip install h5py typing-extensions wheel
# Out:
# /home/alkane/miniconda3/envs/node/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: h5py in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (3.15.1)
# Requirement already satisfied: typing-extensions in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (4.15.0)
# Requirement already satisfied: wheel in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.45.1)
# Requirement already satisfied: numpy>=1.21.2 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from h5py) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install diffrax equinox jax optax scikit-learn scipy dtaidistance fastdtw
# Out:
# Requirement already satisfied: diffrax in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: equinox in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: jax in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.8.2)
# Requirement already satisfied: optax in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.2.6)
# Requirement already satisfied: scikit-learn in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: scipy in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (1.16.3)
# Requirement already satisfied: dtaidistance in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (2.3.13)
# Requirement already satisfied: fastdtw in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (0.3.4)
# Requirement already satisfied: jaxtyping>=0.2.24 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from diffrax) (0.3.4)
# Requirement already satisfied: lineax>=0.0.5 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from diffrax) (0.0.8)
# Requirement already satisfied: optimistix>=0.0.10 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from diffrax) (0.0.11)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from diffrax) (4.15.0)
# Requirement already satisfied: wadler-lindig>=0.1.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from diffrax) (0.1.7)
# Requirement already satisfied: jaxlib<=0.8.2,>=0.8.2 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax) (0.8.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax) (2.4.0)
# Requirement already satisfied: opt_einsum in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax) (3.4.0)
# Requirement already satisfied: absl-py>=0.7.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from optax) (2.3.1)
# Requirement already satisfied: chex>=0.1.87 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from optax) (0.1.91)
# Requirement already satisfied: joblib>=1.3.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: toolz>=1.0.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from chex>=0.1.87->optax) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/justagist/pylasadataset
# Out:
# Collecting git+https://github.com/justagist/pylasadataset
#   Cloning https://github.com/justagist/pylasadataset to /tmp/pip-req-build-gs3ek17_
#   Running command git clone --filter=blob:none --quiet https://github.com/justagist/pylasadataset /tmp/pip-req-build-gs3ek17_
#   Resolved https://github.com/justagist/pylasadataset to commit fad83aa7049f1680114505c3f19abf0c4a2cccc8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from pyLasaDataset==0.1.1) (1.16.3)
# Requirement already satisfied: numpy in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from pyLasaDataset==0.1.1) (2.4.0)
# Requirement already satisfied: matplotlib in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from pyLasaDataset==0.1.1) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (25.0)
# Requirement already satisfied: pillow>=8 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from matplotlib->pyLasaDataset==0.1.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->pyLasaDataset==0.1.1) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import time

import diffrax
import equinox as eqx  # https://github.com/patrick-kidger/equinox
import jax
import jax.nn as jnn
import jax.numpy as jnp
import jax.random as jrandom
import matplotlib.pyplot as plt
import optax  # https://github.com/deepmind/optax
from sklearn.preprocessing import MinMaxScaler
from scipy import interpolate
import numpy as np

# %%
import sys
# !{sys.executable} -m pip uninstall -y jax jaxlib
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U "jax[cuda12]"
# Out:
# /home/alkane/miniconda3/envs/node/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Found existing installation: jax 0.8.2
# Uninstalling jax-0.8.2:
#   Successfully uninstalled jax-0.8.2
# Found existing installation: jaxlib 0.8.2
# Uninstalling jaxlib-0.8.2:
#   Successfully uninstalled jaxlib-0.8.2
# Requirement already satisfied: pip in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (25.3)
# Collecting jax[cuda12]
#   Using cached jax-0.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib<=0.8.2,>=0.8.2 (from jax[cuda12])
#   Using cached jaxlib-0.8.2-cp311-cp311-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax[cuda12]) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax[cuda12]) (2.4.0)
# Requirement already satisfied: opt_einsum in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax[cuda12]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax[cuda12]) (1.16.3)
# Requirement already satisfied: jax-cuda12-plugin<=0.8.2,>=0.8.2 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (0.8.2)
# Requirement already satisfied: jax-cuda12-pjrt==0.8.2 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin<=0.8.2,>=0.8.2->jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (0.8.2)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.1.4)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.79)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.6.85 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.79)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.8 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (9.17.1.4)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (11.4.1.4)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (11.7.5.82)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.5.10.65)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (2.28.9)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12>=12.1.55 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (12.9.86)
# Requirement already satisfied: nvidia-nvshmem-cu12>=3.2.5 in /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages (from jax-cuda12-plugin[with-cuda]<=0.8.2,>=0.8.2; extra == "cuda12"->jax[cuda12]) (3.4.5)
# Using cached jax-0.8.2-py3-none-any.whl (2.9 MB)
# Using cached jaxlib-0.8.2-cp311-cp311-manylinux_2_27_x86_64.whl (80.1 MB)
# Installing collected packages: jaxlib, jax
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [jax]1/2 [jax]
# Successfully installed jax-0.8.2 jaxlib-0.8.2

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# # Load dataset and preprocess

# %%
import pyLasaDataset as lasa

# DataSet object has all the LASA handwriting data files
# as attributes, eg:
angle_data = lasa.DataSet.Angle
sine_data = lasa.DataSet.Sine
Leaf_2_data = lasa.DataSet.Leaf_2
CShape_data = lasa.DataSet.CShape
DoubleBendedLine = lasa.DataSet.DoubleBendedLine

data = lasa.DataSet.Sine


# Each Data object has attributes dt and demos (For documentation,
# refer original dataset repo:
# https://bitbucket.org/khansari/lasahandwritingdataset/src/master/Readme.txt)
dt = data.dt
demos = data.demos # list of 7 Demo objects, each corresponding to a
                         # repetition of the pattern


# Each Demo object in demos list will have attributes pos, t, vel, acc
# corresponding to the original .mat format described in
# https://bitbucket.org/khansari/lasahandwritingdataset/src/master/Readme.txt
demo_0 = demos[1]
pos = demo_0.pos # np.ndarray, shape: (2,2000)
vel = demo_0.vel # np.ndarray, shape: (2,2000)
acc = demo_0.acc # np.ndarray, shape: (2,2000)
t = demo_0.t # np.ndarray, shape: (1,2000)


# To visualise the data (2D position and velocity) use the plot_model utility
lasa.utilities.plot_model(data) # give any of the available
                                                   # pattern data as argument
# Out:
# Using LASA DataSet from /home/alkane/miniconda3/envs/node/lib/python3.11/site-packages/pyLasaDataset/resources/LASAHandwritingDataset/DataSet

# %% [markdown]
# # Define models

# %%
class Func(eqx.Module):
    mlp: eqx.nn.MLP

    def __init__(self, data_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        initializer = jnn.initializers.orthogonal()
        self.mlp = eqx.nn.MLP(
            in_size=data_size,
            out_size=data_size//2,
            width_size=width_size,
            depth=depth,
            activation=jnn.tanh,
            key=key,
        )
        
        keys = jrandom.split(key, len(self.mlp.layers)) 
        for i in range(len(self.mlp.layers)):
            where = lambda m, i=i: m.layers[i].weight
            W = self.mlp.layers[i].weight
            self.mlp = eqx.tree_at(
                where, self.mlp,
                replace=initializer(keys[i], W.shape, dtype=W.dtype)
            )

    @eqx.filter_jit
    def __call__(self, t, y, args):
        x = y[:2]
        v = y[2:]
        a = self.mlp(y)
        return jnp.concatenate([v, a])
        # return self.mlp(yd)

# %%
class Funcd(eqx.Module):
    mlp: eqx.nn.MLP

    def __init__(self, data_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        initializer = jnn.initializers.orthogonal()
        self.mlp = eqx.nn.MLP(
            in_size=2*data_size,
            out_size=data_size,
            width_size=width_size,
            depth=depth,
            activation=jnn.tanh,
            key=key,
        )
        model_key = key
        key_weights = jrandom.split(model_key, depth+1)

        for i in range(depth+1):
          where = lambda m: m.layers[i].weight
          shape = self.mlp.layers[i].weight.shape
          self.mlp = eqx.tree_at(where, self.mlp, replace=initializer(key_weights[i], shape, dtype = jnp.float32))

    @eqx.filter_jit
    def __call__(self, t, yd, args):
        x = yd[:,:2]
        v = yd[:,2:]
        a = self.mlp(yd)
        return jnp.concatenate([v, a])
        # return self.mlp(yd)
        # return self.mlp(jnp.concatenate([yd, jnp.array([t])]))

# %%
class NeuralODE(eqx.Module):
    func: Func
    # metric: "Metric"

    def __init__(self, data_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        self.func = Func(data_size, width_size, depth, key=key)
        # self.metric = Metric(data_size, width_size, depth, key=key)

    def __call__(self, ts, y0):
        solution = diffrax.diffeqsolve(
            diffrax.ODETerm(self.func),
            diffrax.Tsit5(),
            t0=ts[0],
            t1=ts[-1],
            dt0=ts[1] - ts[0],
            y0=y0,
            stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),
            saveat=diffrax.SaveAt(ts=ts),
        )
        return solution.ys

# %%
class NeuralODEd(eqx.Module):
    func: Funcd

    def __init__(self, data_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        self.func = Funcd(data_size, width_size, depth, key=key)

    @eqx.filter_jit
    def __call__(self, ts, yd0):
        solution = diffrax.diffeqsolve(
            diffrax.ODETerm(self.func),
            diffrax.Tsit5(),
            t0=ts[0],
            t1=ts[-1],
            dt0=ts[1] - ts[0],
            y0=yd0,
            stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),
            saveat=diffrax.SaveAt(ts=ts),
        )
        return solution.ys

# %% [markdown]
# # Process data. batch_size $\neq$ dataset_size

# %%
ndemos = len(demos)
T = demos[0].t.shape[-1]
pos_all = []
vel_all = []
for i in range(ndemos):
  pos_all.append((demos[i].pos).T)
  vel_all.append((demos[i].vel).T)
posn = jnp.array(pos_all)
veln = jnp.array(vel_all)
tn =  jnp.array(t.T).reshape(T)
ys_all_n = jnp.concatenate((posn,veln),axis=2)

# %%
nsamples = 1000
ts = t[0]/t[0, -1]
ts_new = jnp.linspace(0, 1, nsamples)

dim = posn.shape[2]

traj_process = jnp.zeros((ndemos, nsamples, dim))
vel_process = jnp.zeros((ndemos, nsamples, dim))

traj_all_t_norm = []
# time_all_process = jnp.zeros((traj_c, nsamples))

seed = 1385

key = jax.random.PRNGKey(seed)
scale_state = 1

key_trajs = jax.random.split(key, num=ndemos)

for i in range(ndemos):
  key_dim = jax.random.split(key_trajs[i], num=dim)
  for j in range(dim):
    f = interpolate.interp1d(ts, posn[i, :, j])
    f_vel = interpolate.interp1d(ts, veln[i, :, j])
    # f = interpolate.interp1d(time_all[i][:, 0], traj_all[i][:, j])
    # ts_new = np.linspace(time_all[i][0, 0], time_all[i][-1, 0], nsamples)
    # time_all_process = time_all_process.at[i].set(ts_new)
    traj_new = f(ts_new)
    vel_new = f_vel(ts_new)
    traj_process = traj_process.at[i, :, j].set(scale_state*traj_new)
    vel_process = vel_process.at[i, :, j].set(scale_state*vel_new)

## Train_Test_split

nTD = 4
traj_train = traj_process[1:nTD]
vel_train = vel_process[1:nTD]

traj_test = traj_process[nTD:]
vel_test = vel_process[nTD:]

## Multi_models

# train_indx = [0, 2, 4, 6]
# nTD = len(train_indx)
# traj_train = jnp.zeros((len(train_indx), nsamples, dim))
# vel_train = jnp.zeros((len(train_indx), nsamples, dim))
# c=0

# for i in train_indx:
#   traj_train = traj_train.at[c].set(traj_process[i])
#   vel_train = vel_train.at[c].set(vel_process[i])
#   c += 1

# test_indx = [1, 3, 5]
# traj_test = jnp.zeros((len(test_indx), nsamples, dim))
# vel_test = jnp.zeros((len(test_indx), nsamples, dim))
# c=0

# for i in test_indx:
#   traj_test = traj_test.at[c].set(traj_process[i])
#   vel_test = vel_test.at[c].set(vel_process[i])
#   c += 1

traj_all_train = jnp.concatenate((traj_train, vel_train), axis=2)
traj_all_test = jnp.concatenate((traj_test, vel_test), axis=2)

# %% [markdown]
# # Dataloader

# %%
def dataloader(arrays, batch_size, *, key):
    dataset_size = arrays[0].shape[0]
    assert all(array.shape[0] == dataset_size for array in arrays)
    indices = jnp.arange(dataset_size)
    while True:
        perm = jrandom.permutation(key, indices)
        (key,) = jrandom.split(key, 1)
        start = 0
        end = batch_size
        while end < dataset_size:
            batch_perm = perm[start:end]
            yield tuple(array[batch_perm] for array in arrays)
            start = end
            end = start + batch_size

# %% [markdown]
# # Train

# %%
def main(
    dataset_size=nTD,
    batch_size=int(nTD/2),
    lr_strategy=(1e-3,),
    steps_strategy=(3000,),
    length_strategy=(1,),
    width_size=128,
    depth=3,
    seed=1000,
    plot=True,
    print_every=100,
    save_every=300,
):
    key = jrandom.PRNGKey(seed)
    data_key, model_key, loader_key = jrandom.split(key, 3)

    ys = traj_train
    ts = tn
    ys_dot = vel_train
    ys_all = traj_all_train

    # ys = posn[:nTD]
    # ts = tn
    # ys_dot = veln[:nTD]
    # ys_all = ys_all_n[:nTD]

    import os
    save_dir = "LASA_models"
    os.makedirs(save_dir, exist_ok=True)

    # file_name = "/content/drive/MyDrive/Colab Notebooks/Neural ODE/LASA_models/CoRL_2023/WShape_checkpoint.eqx"

    # ts, ys, ys_dot = get_data(dataset_size, key=data_key)

    # yst = jnp.copy(ys)

    # scaler = MinMaxScaler()
    # for i in range(dataset_size):
    #   scaler.fit(ys[i])
    #   ysti = scaler.transform(ys[i])
    #   yst = yst.at[i].set(ysti)
    #   # yst = jnp.expand_dims(yst, axis = 0)
    # scaler.fit(ts.reshape(-1,1))
    # tst = scaler.transform(ts.reshape(-1,1))
    # tst = tst.reshape(-1,)

    # ys = yst
    # ts = tst

    _, length_size, data_size = ys_all.shape

    model = NeuralODE(data_size, width_size, depth, key=model_key)

    # Training loop like normal.
    #
    # Only thing to notice is that up until step 500 we train on only the first 10% of
    # each time series. This is a standard trick to avoid getting caught in a local
    # minimum.

    @eqx.filter_value_and_grad
    def grad_loss(model, ti, yi):
        y_pred = jax.vmap(model, in_axes=(None, 0))(ti, yi[:, 0])
        # f = lambda t, z: model.func(t, z, _)
        # y_dot_pred = jax.vmap(jax.vmap(f, in_axes = (0, 0)), in_axes=(None, 0))(ti, yi)
        loss = jnp.mean((yi - y_pred) ** 2)
        # loss = jnp.mean((y_dot_pred - yi_dot)**2)
        return loss

    @eqx.filter_jit
    def make_step(ti, yi, model, opt_state):
        loss, grads = grad_loss(model, ti, yi)
        updates, opt_state = optim.update(grads, opt_state)
        model = eqx.apply_updates(model, updates)
        return loss, model, opt_state

    time_all = 0

    for lr, steps, length in zip(lr_strategy, steps_strategy, length_strategy):
        decay_scheduler = optax.cosine_decay_schedule(lr, decay_steps=steps, alpha=0.95)
        # decay_scheduler = optax.piecewise_constant_schedule(init_value=lr, boundaries_and_scales={int(steps*0.25):0.5, int(steps*0.5):0.5, int(steps*0.75):0.5})
        # decay_scheduler = optax.exponential_decay(init_value=lr, transition_steps=steps, decay_rate=0.98, transition_begin=int(steps*0.25), staircase=False)
        # decay_scheduler = optax.linear_schedule(init_value=lr, end_value=0.005*lr, transition_steps=steps, transition_begin=int(steps*0.25))
        optim = optax.adabelief(learning_rate=decay_scheduler)
        opt_state = optim.init(eqx.filter(model, eqx.is_inexact_array))
        _ts = ts[: int(length_size * length)]
        _ys = ys[:, : int(length_size * length)]
        _ys_dot = ys_dot[:, : int(length_size * length)]
        _ys_all = traj_all_train[:, :int(length_size * length)]
        ## Single trajectory
        # for step in range(steps):
        #   start = time.time()
        #   loss, model, opt_state = make_step(_ts, _ys, _ys_dot, model, opt_state)
        #   end = time.time()
        #   if (step % print_every) == 0 or step == steps - 1:
        #     print(f"Step: {step}, Loss: {loss}, Computation time: {end - start}")
        ## Batches
        best_loss = np.inf
        for step, (yi,) in zip(
            range(steps), dataloader((_ys_all,), batch_size, key=loader_key)
        ):
            start = time.time()
            loss, model, opt_state = make_step(_ts, yi, model, opt_state)
            # loss, model, opt_state = make_step(_ts, _ys, _ys_dot, model, opt_state)
            end = time.time()
            time_all += end - start
            if (step % print_every) == 0 or step == steps - 1:
                print(f"Step: {step}, Loss: {loss}, Computation time: {end - start}")
            if loss < best_loss:
              file_name = f"LASA_models/Sine_semi_Metric_checkpoint_best.eqx"
              eqx.tree_serialise_leaves(file_name, model)
              best_loss = loss

    # if plot:
    #     plt.plot(ts, ys[0, :, 0], c="dodgerblue", label="Real")
    #     plt.plot(ts, ys[0, :, 1], c="dodgerblue")
    #     model_y = model(ts, ys[0, 0])
    #     plt.plot(ts, model_y[:, 0], c="crimson", label="Model")
    #     plt.plot(ts, model_y[:, 1], c="crimson")
    #     plt.legend()
    #     plt.tight_layout()
    #     plt.savefig("neural_ode.png")
    #     plt.show()

    return ts, ys, model, time_all

# %%
ts, ys, model, time_all = main()
# Out:
# Step: 0, Loss: 324.0342102050781, Computation time: 8.14518690109253
# Step: 100, Loss: 59.80457305908203, Computation time: 0.07383894920349121
# Step: 200, Loss: 30.738996505737305, Computation time: 0.1064302921295166
# Step: 300, Loss: 13.160666465759277, Computation time: 0.11125874519348145
# Step: 400, Loss: 10.882694244384766, Computation time: 0.11260485649108887
# Step: 500, Loss: 7.838737487792969, Computation time: 0.10380125045776367
# Step: 600, Loss: 6.619133949279785, Computation time: 0.11144185066223145
# Step: 700, Loss: 9.28355884552002, Computation time: 0.11232590675354004
# Step: 800, Loss: 6.079697608947754, Computation time: 0.10776257514953613
# Step: 900, Loss: 4.649627208709717, Computation time: 0.08802914619445801
# Step: 1000, Loss: 4.816512107849121, Computation time: 0.09770464897155762
# Step: 1100, Loss: 3.708801507949829, Computation time: 0.09473466873168945
# Step: 1200, Loss: 4.7176032066345215, Computation time: 0.1021876335144043
# Step: 1300, Loss: 2.495187520980835, Computation time: 0.10055804252624512
# Step: 1400, Loss: 3.662400484085083, Computation time: 0.10224270820617676
# Step: 1500, Loss: 2.317352294921875, Computation time: 0.11246204376220703
# Step: 1600, Loss: 4.776355743408203, Computation time: 0.10974693298339844
# Step: 1700, Loss: 4.05931282043457, Computation time: 0.10735058784484863
# Step: 1800, Loss: 4.130881309509277, Computation time: 0.113006591796875
# Step: 1900, Loss: 4.064563274383545, Computation time: 0.09926676750183105
# Step: 2000, Loss: 3.535494327545166, Computation time: 0.09640860557556152
# Step: 2100, Loss: 3.7872629165649414, Computation time: 0.10524535179138184
# Step: 2200, Loss: 4.426897048950195, Computation time: 0.10630655288696289
# Step: 2300, Loss: 4.070108890533447, Computation time: 0.09192991256713867
# Step: 2400, Loss: 3.2980642318725586, Computation time: 0.09592366218566895
# Step: 2500, Loss: 2.2931768894195557, Computation time: 0.10196232795715332
# Step: 2600, Loss: 4.108280658721924, Computation time: 0.10763311386108398
# Step: 2700, Loss: 3.3808507919311523, Computation time: 0.12213516235351562
# Step: 2800, Loss: 4.084604740142822, Computation time: 0.10708189010620117
# Step: 2900, Loss: 4.2866692543029785, Computation time: 0.1245725154876709
# Step: 2999, Loss: 1.9021353721618652, Computation time: 0.11345863342285156

# %% [markdown]
# # Plot predicted trajectories

# %%
train_indx = 0
plt.plot(posn[train_indx, :, 0], posn[train_indx, :, 1], c="dodgerblue", label="Real")
plt.plot(posn[train_indx, 0, 0], posn[train_indx, 0, 1], c="black", marker='o', markersize = '12', label="Start")
plt.plot(posn[train_indx, -1, 0], posn[train_indx, -1, 1], c="black", marker='x', markersize = '12', label="Target")
model_y = model(2*ts, ys_all_n[train_indx, 0])
plt.plot(model_y[:, 0], model_y[:, 1], c="crimson", label="Model")
model_y = model(2*ts, ys_all_n[train_indx, 0] + np.array([0, 15, 0, 0]))
plt.plot(model_y[:, 0], model_y[:, 1], c="crimson", label="Model")
model_y = model(2*ts, ys_all_n[train_indx, 0] + np.array([5, 0, 0, 0]))
plt.plot(model_y[:, 0], model_y[:, 1], c="crimson", label="Model")
plt.legend()
plt.tight_layout()
plt.savefig("neural_ode.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp


def plot_zero_velocity_acceleration_field(
    model,
    x1_min, x1_max,
    x2_min, x2_max,
    grid_size=80,          # 网格密度，60~100 推荐
    density=2.0,           # 流线密度
    linewidth=0.6,         # 线宽（越小越细）
    arrowsize=0.8,         # 箭头大小
):

    # ------------------------------------------------
    # 1) 位置网格
    # ------------------------------------------------
    x1 = np.linspace(x1_min, x1_max, grid_size)
    x2 = np.linspace(x2_min, x2_max, grid_size)
    X1, X2 = np.meshgrid(x1, x2)

    # ------------------------------------------------
    # 2) 构造状态 y = [x, v=0]
    # ------------------------------------------------
    pts = np.stack([X1.ravel(), X2.ravel()], axis=1)   # (N,2)
    v0 = np.zeros_like(pts)                            # 固定 v = 0
    Y = np.concatenate([pts, v0], axis=1)              # (N,4)
    Yj = jnp.asarray(Y)

    # ------------------------------------------------
    # 3) 计算加速度 a(x,0)
    # ------------------------------------------------
    f = lambda y: model.func(0.0, y, None)
    dydt = jax.vmap(f)(Yj)          # (N,4)

    A = np.asarray(dydt[:, 2:])     # 只取加速度部分
    Ax = A[:, 0].reshape(X1.shape)
    Ay = A[:, 1].reshape(X2.shape)

    # ------------------------------------------------
    # 4) 归一化（只保留方向）
    # ------------------------------------------------
    norm = np.hypot(Ax, Ay) + 1e-9
    Ax_n = Ax / norm
    Ay_n = Ay / norm

    # ------------------------------------------------
    # 5) 画流线
    # ------------------------------------------------
    fig, ax = plt.subplots(figsize=(4, 3), dpi=150)

    ax.streamplot(
        X1, X2,
        Ax_n, Ay_n,
        density=density,
        linewidth=linewidth,
        arrowsize=arrowsize,
        color=(0.75, 0.4, 0.8, 0.45),   # 淡紫色，论文常见
        zorder=1
    )

    ax.set_xlim(x1_min, x1_max)
    ax.set_ylim(x2_min, x2_max)
    ax.set_aspect("equal", adjustable="box")
    ax.set_xlabel(r"$x_1$", fontsize=16)
    ax.set_ylabel(r"$x_2$", fontsize=16)
    ax.tick_params(labelsize=12)
    plt.tight_layout()
    plt.show()

plot_zero_velocity_acceleration_field(
    model,
    x1_min=-50, x1_max=0,
    x2_min=-10, x2_max=30,
    grid_size=5,
    density=1,
    linewidth=0.5,
    arrowsize=0.7,
)

# %% [markdown]
# # Save the model

# %%
import os
file_name = "LASA_models/Sine_semi_Metric_checkpoint_best.eqx"
save_dir = "LASA_models"
os.makedirs(save_dir, exist_ok=True)

eqx.tree_serialise_leaves(file_name, model)

# %% [markdown]
# # Load the model

# %%
file_name = "LASA_models/Sine_semi_Metric_checkpoint_best.eqx"
# file_name = "/content/drive/MyDrive/Colab Notebooks/Neural ODE/Tunnel_no_d_checkpoint.eqx"
ys = posn
ts = tn
ys_dot = veln
_, length_size, data_size = ys_all_n.shape
width_size=128
depth=3
seed=1000
key = jrandom.PRNGKey(seed)
data_key, model_key, loader_key = jrandom.split(key, 3)
model1 = NeuralODE(data_size, width_size, depth, key=model_key)
model_load_1 = eqx.tree_deserialise_leaves(file_name, model1)

# %% [markdown]
# # Plot predicted trajectories

# %%
y_pred = jax.vmap(model_load_1, in_axes=(None, 0))(ts, ys_all_n[:, 0])

# %%
for i in range(5, 6):
  plt.plot(y_pred[i, :, 0], y_pred[i, :, 1])
  plt.plot(posn[i, :, 0], posn[i, :, 1])
